# %%
# pip install apyori

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from apyori import apriori

# %%
store_data = pd.read_csv('https://raw.githubusercontent.com/vsrekha213/Web-Mining/main/store_data.csv')

# %%
records = []
for i in range(0, 10):
    records.append([str(store_data.values[i,j]) for j in range(0, 20)])

# %%
association_rules = apriori(records, min_support=0.0045, min_confidence=0.2, min_lift=3, min_length=2)
association_results = list(association_rules)

# %%
for item in association_results:
    # first index of the inner list
    # Contains base item and add item
    pair = item[0] 
    items = [x for x in pair]
    print("Rule: " + items[0] + " -> " + items[1])

    print("Confidence: " + str(item[2][0][2]))
    print("=====================================")
# Out:
# Rule: turkey -> avocado
# Confidence: 1.0
# =====================================
# Rule: burgers -> eggs
# Confidence: 1.0
# =====================================
# Rule: burgers -> meatballs
# Confidence: 1.0
# =====================================
# Rule: meatballs -> eggs
# Confidence: 0.5
# =====================================
# Rule: pet food -> eggs
# Confidence: 0.5
# =====================================
# Rule: energy bar -> green tea
# Confidence: 1.0
# =====================================
# Rule: energy bar -> milk
# Confidence: 1.0
# =====================================
# Rule: energy bar -> mineral water
# Confidence: 1.0
# =====================================
# Rule: energy bar -> whole wheat rice
# Confidence: 1.0
# =====================================
# Rule: whole wheat pasta -> french fries
# Confidence: 0.5
# =====================================
# Rule: frozen vegetables -> green tea
# Confidence: 1.0
# =====================================
# Rule: frozen vegetables -> spaghetti
# Confidence: 1.0
# =====================================
# Rule: milk -> green tea
# Confidence: 0.5
# =====================================
# Rule: green tea -> mineral water
# Confidence: 0.5
# =====================================
# Rule: spaghetti -> green tea
# Confidence: 0.5
# =====================================
# Rule: green tea -> whole wheat rice
# Confidence: 0.5
# =====================================
# Rule: shallot -> light cream
# Confidence: 1.0
# =====================================
# Rule: soup -> light cream
# Confidence: 1.0
# =====================================
# Rule: milk -> mineral water
# Confidence: 1.0
# =====================================
# Rule: milk -> whole wheat rice
# Confidence: 1.0
# =====================================
# Rule: whole wheat rice -> mineral water
# Confidence: 1.0
# =====================================
# Rule: soup -> shallot
# Confidence: 1.0
# =====================================
# Rule: nan -> turkey
# Confidence: 1.0
# =====================================
# Rule: burgers -> meatballs
# Confidence: 1.0
# =====================================
# Rule: burgers -> nan
# Confidence: 1.0
# =====================================
# Rule: burgers -> nan
# Confidence: 1.0
# =====================================
# Rule: nan -> meatballs
# Confidence: 0.5
# =====================================
# Rule: nan -> pet food
# Confidence: 0.5
# =====================================
# Rule: energy bar -> milk
# Confidence: 1.0
# =====================================
# Rule: energy bar -> green tea
# Confidence: 1.0
# =====================================
# Rule: energy bar -> nan
# Confidence: 1.0
# =====================================
# Rule: energy bar -> green tea
# Confidence: 1.0
# =====================================
# Rule: energy bar -> milk
# Confidence: 1.0
# =====================================
# Rule: nan -> energy bar
# Confidence: 1.0
# =====================================
# Rule: energy bar -> milk
# Confidence: 1.0
# =====================================
# Rule: energy bar -> nan
# Confidence: 1.0
# =====================================
# Rule: energy bar -> whole wheat rice
# Confidence: 1.0
# =====================================
# Rule: energy bar -> nan
# Confidence: 1.0
# =====================================
# Rule: whole wheat pasta -> nan
# Confidence: 0.5
# =====================================
# Rule: nan -> frozen vegetables
# Confidence: 1.0
# =====================================
# Rule: spaghetti -> frozen vegetables
# Confidence: 1.0
# =====================================
# Rule: nan -> frozen vegetables
# Confidence: 1.0
# =====================================
# Rule: milk -> green tea
# Confidence: 0.5
# =====================================
# Rule: nan -> milk
# Confidence: 0.5
# =====================================
# Rule: milk -> green tea
# Confidence: 0.5
# =====================================
# Rule: nan -> green tea
# Confidence: 0.5
# =====================================
# Rule: green tea -> whole wheat rice
# Confidence: 0.5
# =====================================
# Rule: nan -> green tea
# Confidence: 0.5
# =====================================
# Rule: nan -> green tea
# Confidence: 0.5
# =====================================
# Rule: nan -> shallot
# Confidence: 1.0
# =====================================
# Rule: soup -> nan
# Confidence: 1.0
# =====================================
# Rule: soup -> shallot
# Confidence: 1.0
# =====================================
# Rule: nan -> milk
# Confidence: 1.0
# =====================================
# Rule: milk -> whole wheat rice
# Confidence: 1.0
# =====================================
# Rule: nan -> milk
# Confidence: 1.0
# =====================================
# Rule: nan -> whole wheat rice
# Confidence: 1.0
# =====================================
# Rule: soup -> nan
# Confidence: 1.0
# =====================================
# Rule: burgers -> nan
# Confidence: 1.0
# =====================================
# Rule: energy bar -> milk
# Confidence: 1.0
# =====================================
# Rule: nan -> energy bar
# Confidence: 1.0
# =====================================
# Rule: energy bar -> milk
# Confidence: 1.0
# =====================================
# Rule: energy bar -> nan
# Confidence: 1.0
# =====================================
# Rule: energy bar -> green tea
# Confidence: 1.0
# =====================================
# Rule: energy bar -> nan
# Confidence: 1.0
# =====================================
# Rule: nan -> energy bar
# Confidence: 1.0
# =====================================
# Rule: energy bar -> milk
# Confidence: 1.0
# =====================================
# Rule: nan -> energy bar
# Confidence: 1.0
# =====================================
# Rule: energy bar -> nan
# Confidence: 1.0
# =====================================
# Rule: nan -> frozen vegetables
# Confidence: 1.0
# =====================================
# Rule: nan -> milk
# Confidence: 0.5
# =====================================
# Rule: milk -> green tea
# Confidence: 0.5
# =====================================
# Rule: nan -> milk
# Confidence: 0.5
# =====================================
# Rule: nan -> green tea
# Confidence: 0.5
# =====================================
# Rule: soup -> nan
# Confidence: 1.0
# =====================================
# Rule: nan -> milk
# Confidence: 1.0
# =====================================
# Rule: nan -> milk
# Confidence: 1.0
# =====================================
# Rule: milk -> mineral water
# Confidence: 1.0
# =====================================
# Rule: nan -> milk
# Confidence: 1.0
# =====================================
# Rule: nan -> mineral water
# Confidence: 1.0
# =====================================
# Rule: nan -> milk
# Confidence: 1.0
# =====================================
# Rule: nan -> milk
# Confidence: 0.5
# =====================================
# Rule: nan -> milk
# Confidence: 1.0
# =====================================
